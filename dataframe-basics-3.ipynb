# %%
import numpy as np
import pandas as pd

# %%
tit_wrk1 = pd.read_csv("Titanic-Dataset.csv")
tit_wrk1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
(  (  tit_wrk1['Age'] > 10.0  )  &  (  tit_wrk1['Sex'] == 'male'  ) )
# return a series of True / False values.
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Length: 891, dtype: bool

# %%
tit_wrk1[  (  tit_wrk1['Age'] > 10.0  )  &  (  tit_wrk1['Sex'] == 'male'  ) ]
# index is scattered
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# 13            14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
tit_wrk1[  (  tit_wrk1['Age'] > 10.0  )  &  (  tit_wrk1['Sex'] == 'male'  ) ].reset_index()
# reset datframe's index starting from 0 to end of data.csv i.e to get index in a chronological order
# index appears as a new column again.
# Out:
#      index  PassengerId  Survived  Pclass                            Name  \
# 0        0            1         0       3         Braund, Mr. Owen Harris
# 1        4            5         0       3        Allen, Mr. William Henry
# 2        6            7         0       1         McCarthy, Mr. Timothy J
# 3       12           13         0       3  Saundercock, Mr. William Henry
# 4       13           14         0       3     Andersson, Mr. Anders Johan
# ..     ...          ...       ...     ...                             ...
# 415    883          884         0       2   Banfield, Mr. Frederick James
# 416    884          885         0       3          Sutehall, Mr. Henry Jr
# 417    886          887         0       2           Montvila, Rev. Juozas
# 418    889          890         1       1           Behr, Mr. Karl Howell
# 419    890          891         0       3             Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
tit_wrk1[  (  tit_wrk1['Age'] > 10.0  )  &  (  tit_wrk1['Sex'] == 'male'  ) ].reset_index().drop(columns='index')
# reset datframe's index starting from 0 to end of data.csv
# index appears as a new column again.
# drop the older 'index' column.
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 1              5         0       3        Allen, Mr. William Henry  male
# 2              7         0       1         McCarthy, Mr. Timothy J  male
# 3             13         0       3  Saundercock, Mr. William Henry  male
# 4             14         0       3     Andersson, Mr. Anders Johan  male
# ..           ...       ...     ...                             ...   ...
# 415          884         0       2   Banfield, Mr. Frederick James  male
# 416          885         0       3          Sutehall, Mr. Henry Jr  male
# 417          887         0       2           Montvila, Rev. Juozas  male
# 418          890         1       1           Behr, Mr. Karl Howell  male
# 419          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
brics_wrk1 = pd.read_csv("brics.csv")
brics_wrk1 # pandas auto creates an index column.
# Out:
#   Code       country    capital    area  population
# 0   BR        Brazil   Brasilia   8.516      200.40
# 1   RU        Russia     Moscow  17.100      143.50
# 2   IN         India  New Delhi   3.286     1252.00
# 3   CH         China    Beijing   9.597     1357.00
# 4   SA  South Africa   Pretoria   1.221       52.98

# %%
brics_wrk2 = pd.read_csv("brics.csv", index_col=0) # create row labels by indexing the 'Code' column
brics_wrk2 # index column or row should be unique. Row labels are unique as created.
# Out:
#            country    capital    area  population
# Code
# BR          Brazil   Brasilia   8.516      200.40
# RU          Russia     Moscow  17.100      143.50
# IN           India  New Delhi   3.286     1252.00
# CH           China    Beijing   9.597     1357.00
# SA    South Africa   Pretoria   1.221       52.98

# %%
#use row labels to slice data
brics_wrk2.loc["IN"]
# Out:
# country           India
# capital       New Delhi
# area              3.286
# population       1252.0
# Name: IN, dtype: object

# %%
#use row labels to slice data
brics_wrk2.loc[["IN"]]
# Out:
#      country    capital   area  population
# Code
# IN     India  New Delhi  3.286      1252.0

# %%
brics_wrk2.loc[["SA","IN","CH"]] # slicing on row labels.
# Out:
#            country    capital   area  population
# Code
# SA    South Africa   Pretoria  1.221       52.98
# IN           India  New Delhi  3.286     1252.00
# CH           China    Beijing  9.597     1357.00

# %%
brics_wrk2.loc[["SA","IN","CH"], ['capital','population']] # slicing on row & column labels . #df[ [row1,..rown], [col1, .. coln]  ]
# Out:
#         capital  population
# Code
# SA     Pretoria       52.98
# IN    New Delhi     1252.00
# CH      Beijing     1357.00

# %%
brics_wrk2
# Out:
#            country    capital    area  population
# Code
# BR          Brazil   Brasilia   8.516      200.40
# RU          Russia     Moscow  17.100      143.50
# IN           India  New Delhi   3.286     1252.00
# CH           China    Beijing   9.597     1357.00
# SA    South Africa   Pretoria   1.221       52.98

# %%
# slice based on index positions - iloc
brics_wrk2.iloc[2]
# Out:
# country           India
# capital       New Delhi
# area              3.286
# population       1252.0
# Name: IN, dtype: object

# %%
type(brics_wrk2.iloc[2])
# Out:
# pandas.core.series.Series

# %%
brics_wrk2.iloc[[2]]
# Out:
#      country    capital   area  population
# Code
# IN     India  New Delhi  3.286      1252.0

# %%
brics_wrk2.iloc[[2,3,1]]
# Out:
#      country    capital    area  population
# Code
# IN     India  New Delhi   3.286      1252.0
# CH     China    Beijing   9.597      1357.0
# RU    Russia     Moscow  17.100       143.5

# %%
brics_wrk2.iloc[[2,3,1],[0]]
# Out:
#      country
# Code
# IN     India
# CH     China
# RU    Russia

# %%
brics_wrk2.iloc[[2,3,1],[0,3]]
# Out:
#      country  population
# Code
# IN     India      1252.0
# CH     China      1357.0
# RU    Russia       143.5

# %%
# concept of sequence can be used in iloc
brics_wrk2.iloc[1:3, ]
# Out:
#      country    capital    area  population
# Code
# RU    Russia     Moscow  17.100       143.5
# IN     India  New Delhi   3.286      1252.0

# %%
# concept of sequence can be used in iloc
brics_wrk2.iloc[1:3, 1:4]
# Out:
#         capital    area  population
# Code
# RU       Moscow  17.100       143.5
# IN    New Delhi   3.286      1252.0

# %%
brics_wrk2
# Out:
#            country    capital    area  population
# Code
# BR          Brazil   Brasilia   8.516      200.40
# RU          Russia     Moscow  17.100      143.50
# IN           India  New Delhi   3.286     1252.00
# CH           China    Beijing   9.597     1357.00
# SA    South Africa   Pretoria   1.221       52.98

# %%
brics_wrk2.shape
# Out:
# (5, 4)

# %%
brics_wrk2.iloc[0]
# Out:
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object

# %%
brics_wrk2.iloc[[0]]
# Out:
#      country   capital   area  population
# Code
# BR    Brazil  Brasilia  8.516       200.4

# %%
brics_wrk2.iloc[[0,1]]
# Out:
#      country   capital    area  population
# Code
# BR    Brazil  Brasilia   8.516       200.4
# RU    Russia    Moscow  17.100       143.5

# %%
brics_wrk2.iloc[0,0]
# Out:
# 'Brazil'

# %%
brics_wrk2.iloc[0,1]
# Out:
# 'Brasilia'

# %%
brics_wrk2.iloc[0,2]
# Out:
# np.float64(8.516)

# %%
brics_wrk2.iloc[0:3,2:4]
# Out:
#         area  population
# Code
# BR     8.516       200.4
# RU    17.100       143.5
# IN     3.286      1252.0

# %%
tit_wrk1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit_wrk1["Fare in Indian Rupees"] = tit_wrk1["Fare"] * 87.31
tit_wrk1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
tit_wrk1.duplicated()
# Out:
# np.int64(0)

# %%
tit_wrk1.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_wrk1 = pd.DataFrame({
    "brand": ['yum', 'yum', 'ind'],
    "style": ['cup', 'bottle', 'bottle']
})
df_wrk1
# Out:
#   brand   style
# 0   yum     cup
# 1   yum  bottle
# 2   ind  bottle

# %%
df_wrk1.duplicated(subset=['brand'])
# Out:
# 0    False
# 2    False
# dtype: bool

# %%
# drop particular duplicated column only
df_wrk1.drop_duplicates(subset=['brand'], inplace=True)

# %%
df_wrk1
# Out:
#   brand   style
# 0   yum     cup
# 2   ind  bottle

# %%
tit_wrk1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Fare in Indian Rupees
# 0      0         A/5 21171   7.2500   NaN        S             632.997500
# 1      0          PC 17599  71.2833   C85        C            6223.744923
# 2      0  STON/O2. 3101282   7.9250   NaN        S             691.931750
# ...

# %%
tit_wrk1.groupby(["Pclass","Survived"])[["Fare","Age"]].sum()
# Out:
#                        Fare      Age
# Pclass Survived
# 1      0          5174.7206  2796.50
#        1         13002.6919  4314.92
# 2      0          1882.9958  3019.00
#        1          1918.8459  2149.83
# 3      0          5085.0035  7170.00
#        1          1629.6916  1754.92

# %%
tit_wrk1.groupby(["Pclass","Survived"])[["Fare","Age"]].mean()
# Out:
#                       Fare        Age
# Pclass Survived
# 1      0         64.684007  43.695312
#        1         95.608029  35.368197
# 2      0         19.412328  33.544444
#        1         22.055700  25.901566
# 3      0         13.669364  26.555556
#        1         13.694887  20.646118

# %%
tit_wrk1.sort_values(by=["Pclass","Age"] , ascending=[True,False]  )
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 630          631         1       1      Barkworth, Mr. Algernon Henry Wilson
# 96            97         0       1                 Goldschmidt, Mr. George B
# 493          494         0       1                   Artagaveytia, Mr. Ramon
# 745          746         0       1              Crosby, Capt. Edward Gifford
# 54            55         0       1            Ostby, Mr. Engelhart Cornelius
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
tit_wrk1.sort_values(by=["Pclass","Age"] , ascending=[True,True]  )
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 305          306         1       1            Allison, Master. Hudson Trevor
# 297          298         0       1              Allison, Miss. Helen Loraine
# 445          446         1       1                 Dodge, Master. Washington
# 802          803         1       1       Carter, Master. William Thornton II
# 435          436         1       1                 Carter, Miss. Lucile Polk
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
tit_wrk1.isna().sum() # detect missing values in each column.
# Out:
# PassengerId                0
# Survived                   0
# Pclass                     0
# Name                       0
# Sex                        0
# Age                      177
# SibSp                      0
# Parch                      0
# Ticket                     0
# Fare                       0
# Cabin                    687
# Embarked                   2
# Fare in Indian Rupees      0
# dtype: int64

# %% [markdown]
# replacement of missing values:
#
# 1. with some constant
#
# 2. mean of the calories column
#
# 3. median of the calories column
#
# 4. mode -(advisable with categorical cols)

# %%
df_drt_dat = pd.read_csv('dirtydata.csv')
df_drt_dat
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
dated_formatted  = pd.to_datetime(df_drt_dat['Date'],format='mixed')
dated_formatted
# Out:
# 0    2020-12-01
# 1    2020-12-02
# 2    2020-12-03
# 3    2020-12-04
# 4    2020-12-05
# 5    2020-12-06
# 6    2020-12-07
# 7    2020-12-08
# 8    2020-12-09
# 9    2020-12-10
# 10   2020-12-11
# 11   2020-12-12
# 12   2020-12-12
# 13   2020-12-13
# 14   2020-12-14
# 15   2020-12-15
# 16   2020-12-16
# 17   2020-12-17
# 18   2020-12-18
# 19   2020-12-19
# 20   2020-12-20
# 21   2020-12-21
# 22          NaT
# 23   2020-12-23
# 24   2020-12-24
# 25   2020-12-25
# 26   2020-12-26
# 27   2020-12-27
# 28   2020-12-28
# 29   2020-12-29
# 30   2020-12-30
# 31   2020-12-31
# Name: Date, dtype: datetime64[ns]

# %%
df_drt_dat['Date'] = dated_formatted

# %%
df_drt_dat
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130     409.1
# 1         60 2020-12-02    117       145     479.0
# 2         60 2020-12-03    103       135     340.0
# 3         45 2020-12-04    109       175     282.4
# 4         45 2020-12-05    117       148     406.0
# 5         60 2020-12-06    102       127     300.0
# 6         60 2020-12-07    110       136     374.0
# 7        450 2020-12-08    104       134     253.3
# 8         30 2020-12-09    109       133     195.1
# 9         60 2020-12-10     98       124     269.0
# 10        60 2020-12-11    103       147     329.3
# 11        60 2020-12-12    100       120     250.7
# 12        60 2020-12-12    100       120     250.7
# 13        60 2020-12-13    106       128     345.3
# 14        60 2020-12-14    104       132     379.3
# 15        60 2020-12-15     98       123     275.0
# 16        60 2020-12-16     98       120     215.2
# ...
